# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
# !pwd
# Out:
# /home/anilla/DataScience/Kaggle/Kaggle_CareerCon_2019

# %%
Dataset=pd.read_csv('/home/anilla/DataScience/Kaggle/Kaggle_CareerCon_2019/X_train.csv')

# %%
Labels=pd.read_csv('/home/anilla/DataScience/Kaggle/Kaggle_CareerCon_2019/y_train.csv')

# %%
Dataset.head(10)
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
# 5    0_5          0                   5       -0.75853       -0.63439
# 6    0_6          0                   6       -0.75853       -0.63441
# 7    0_7          0                   7       -0.75852       -0.63444
# 8    0_8          0                   8       -0.75851       -0.63445
# 9    0_9          0                   9       -0.75851       -0.63443
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
# 5       -0.10483       -0.10580            0.059664            0.013043
# 6       -0.10481       -0.10569            0.082140            0.044356
# 7       -0.10480       -0.10561            0.056218            0.038162
# 8       -0.10485       -0.10559           -0.012846            0.039004
# 9       -0.10489       -0.10567           -0.090082            0.027299
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000767               -0.74857               2.103000
# 1            0.003385                0.33995               1.506400
# 2           -0.005978               -0.26429               1.592200
# 3           -0.008974                0.42684               1.099300
# 4            0.005245               -0.50969               1.468900
# 5           -0.013231               -0.44745               0.992810
# 6           -0.002696               -0.14163               0.734970
# 7           -0.022931               -0.12160               0.075417
# 8           -0.007831                1.60000               0.816110
# 9           -0.009970                0.47496               0.909600
#
#    linear_acceleration_Z
# 0                -9.7532
# 1                -9.4128
# 2                -8.7267
# 3               -10.0960
# 4               -10.4410
# 5               -10.4020
# 6                -9.4296
# 7                -8.6088
# 8                -7.6426
# 9                -8.8120

# %%
Labels.head(10)
# Out:
#    series_id  group_id                 surface
# 0          0        13           fine_concrete
# 1          1        31                concrete
# 2          2        20                concrete
# 3          3        31                concrete
# 4          4        22              soft_tiles
# 5          5         1                   tiled
# 6          6        34                soft_pvc
# 7          7        31                concrete
# 8          8        33  hard_tiles_large_space
# 9          9        11                   tiled

# %%
Labels['surface'].unique()
# Out:
# array(['fine_concrete', 'concrete', 'soft_tiles', 'tiled', 'soft_pvc',
#        'hard_tiles_large_space', 'carpet', 'hard_tiles', 'wood'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
label_encoder=LabelEncoder()

# %%
one_hot=OneHotEncoder(sparse=False)
